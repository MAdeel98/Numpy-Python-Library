# %%
# Lets begin the Pandas

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
my_list=[10,20,30,40]
arr=np.array([10,20,30,40])
labels=["a","b","c","d"]
d={1:20,2:20,3:30,4:40}

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    20
# 2    20
# 3    30
# 4    40
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

# %%
pd.DataFrame(data_list,index=labels)
# Out:
#        0   1         2      3
# a   John  28  New York  65000
# b   Anna  34     Paris  70000
# c  Peter  29    Berlin  62000
# d  Linda  42    London  85000

# %%
columns=["name","Age","City","Salary"]
df=pd.DataFrame(data_list,columns=columns)
df
# Out:
#     name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df[['name','Salary','City']]
# Out:
#     name  Salary      City
# 0   John   65000  New York
# 1   Anna   70000     Paris
# 2  Peter   62000    Berlin
# 3  Linda   85000    London

# %%
df['designation']=['engr','doct','artist','singer']
df
# Out:
#     name  Age      City  Salary designation
# 0   John   28  New York   65000        engr
# 1   Anna   34     Paris   70000        doct
# 2  Peter   29    Berlin   62000      artist
# 3  Linda   42    London   85000      singer

# %%
df
# Out:
#     name  Age      City  Salary designation
# 0   John   28  New York   65000        engr
# 1   Anna   34     Paris   70000        doct
# 2  Peter   29    Berlin   62000      artist
# 3  Linda   42    London   85000      singer

# %%
df.drop("designation",axis=1,inplace=True)

# %%
df
# Out:
#     name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.drop(0,axis=0)
# Out:
#     name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
df
# Out:
#     name  Age      City  Salary        4
# 0   John   28  New York   65000    Adeel
# 1   Anna   34     Paris   70000       19
# 2  Peter   29    Berlin   62000  Karachi
# 3  Linda   42    London   85000    56700

# %%
df.drop(4,axis=1,inplace=True)

# %%
df
# Out:
#     name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[1,2]][["name",'City']]
# Out:
#     name    City
# 1   Anna   Paris
# 2  Peter  Berlin

# %%
df.iloc[3]
# Out:
# name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
df[(df['Age']>30) & (df['City']=="Paris")]
# Out:
#    name  Age   City  Salary
# 1  Anna   34  Paris   70000
