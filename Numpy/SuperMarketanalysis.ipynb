# %%
import numpy as np

# %%
sales = np.array([
    [1200,1500,1700,1300],
    [1400,1600,1800,1500],
    [1700,1800,2100,1900],
    [1300,1200,1400,1500],
    [1800,2000,2200,2100]
])

# %%
# Total_Rev=np.sum(sales[:,:])
# Total_Rev
Total_Rev=sales[:].sum(axis=1)
for i ,c in enumerate(Total_Rev,start=1):
    print(f"{i} : {Total_Rev[i-1]}")
# Out:
# 1 : 5700
# 2 : 6300
# 3 : 7500
# 4 : 5400
# 5 : 8100

# %%
# Find the total weekly revenue generated by each product.
Total_Rev=sales[:].sum(axis=0)
# for i ,c in enumerate(Total_Rev,start=1):
#     print(f"{i} : {Total_Rev[i-1]}")
Total_Rev
# Out:
# array([7400, 8100, 9200, 8300])

# %%
# Task 3 — Average Sales
# Description

# Find

# Average sales per day
# Average sales per product

# %%
sales.mean(axis=1)
# Out:
# array([1425., 1575., 1875., 1350., 2025.])

# %%
sales.mean(axis=0)
# Out:
# array([1480., 1620., 1840., 1660.])

# %%
Total_Rev.max()
# Out:
# np.int64(9200)

# %% [markdown]
# ADDING ANOTHER PRODUCT OR COLUMN IN DATA SET :

# %%
z=np.array([1000,1100,1200,900,1300])
np.column_stack((sales,z))
# Out:
# array([[1200, 1500, 1700, 1300, 1000, 1000],
#        [1400, 1600, 1800, 1500, 1100, 1100],
#        [1700, 1800, 2100, 1900, 1200, 1200],
#        [1300, 1200, 1400, 1500,  900,  900],
#        [1800, 2000, 2200, 2100, 1300, 1300]])

# %%
days=["monday","tuesday","thursday","friday","saturday"]
n=sales[0,:].sum()
hj=[days[0]]
print(f"{n} :{hj}")
# Out:
# 6700 :['monday']

# %%
sales
# Out:
# array([[1200, 1500, 1700, 1300, 1000],
#        [1400, 1600, 1800, 1500, 1100],
#        [1700, 1800, 2100, 1900, 1200],
#        [1300, 1200, 1400, 1500,  900],
#        [1800, 2000, 2200, 2100, 1300]])

# %%
# highest individuals
products = ["Bread", "Milk", "Rice", "Eggs"]
row, col = np.unravel_index(sales.argmax(), sales.shape)

print("Day:", days[row])
print("Product:", products[col])
print("Sale:", sales[row, col])
# Out:
# Day: saturday
# Product: Rice
# Sale: 2200
